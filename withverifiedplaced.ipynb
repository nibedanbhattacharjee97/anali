# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('education_Verified_Placed.xlsx')

# %%
df
# Out:
#        StudentID                Name  Age Gender  \
# 0              1           Apu Naiya   19      M
# 1              2   Mrityunjoy Naskar   21      M
# 2              3      SUPARNA HALDER   22      F
# 3              4           PARVEJ SK   23      M
# 4              5       DIPANKAR HAIT   22      M
# ...          ...                 ...  ...    ...
# 39851      39852        Aditi Baidya   21      F
# 39852      39853           Tithi Roy   26      F
# 39853      39854         RIMI KHATUN   19      F
# 39854      39855    SUJAUDDIN AHAMED   21      M
# 39855      39856  ARINDAM CHATTERJEE   21      M
#
#                                                   Course  StartDate  \
# 0      Certificate in Professional and Future Skills ... 2023-04-20
# 1      Certificate in Professional and Future Skills ... 2023-04-20
# 2      Certificate in Professional and Future Skills ... 2023-04-20
# 3      Certificate in English Communication and IT Fu... 2023-10-11
# ...

# %%
gen = df.groupby('Gender').agg(
    placerate = ('PlacementStatus', lambda X: (X == 'Placed').mean() * 100),
    ).reset_index()

# %%
gen
# Out:
#     Gender  placerate
# 0        F  21.380868
# 1        M  21.568215
# 2  epicene  26.666667
